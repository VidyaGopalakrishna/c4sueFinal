# %%
#Important Dates
#Before Katrina = 2004.csv
#During Katrina = 2005.csv
#After Katrina = 2006.csv
#Hurricane Katrina = Aug 23 2005 - Aug 31 2005
#Gulf Coast States = Texas, Alabama, Mississippi, Louisiana, Florida

# %%
import pandas as pd
import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df04 = pd.read_excel('2004.xls')
df05 = pd.read_excel('2005.xls')
df06 = pd.read_excel('2006.xls')

# %%
PersonalIncome04 = pd.DataFrame(df04.loc[df04['LineCode'] == 1],columns=['GeoName', 'data'])
Population04 = pd.DataFrame(df04.loc[df04['LineCode'] == 2],columns=['GeoName', 'data'])
PerCapita04 = pd.DataFrame(df04.loc[df04['LineCode'] == 3],columns=['GeoName', 'data'])

# %%
PersonalIncome05 = pd.DataFrame(df05.loc[df05['LineCode'] == 1],columns=['GeoName', 'data'])
Population05 = pd.DataFrame(df05.loc[df05['LineCode'] == 2],columns=['GeoName', 'data'])
PerCapita05 = pd.DataFrame(df05.loc[df05['LineCode'] == 3],columns=['GeoName', 'data'])

# %%
PersonalIncome06 = pd.DataFrame(df06.loc[df06['LineCode'] == 1],columns=['GeoName', 'data'])
Population06 = pd.DataFrame(df06.loc[df06['LineCode'] == 2],columns=['GeoName', 'data'])
PerCapita06 = pd.DataFrame(df06.loc[df06['LineCode'] == 3],columns=['GeoName', 'data'])

# %%
PersonalIncome04.shape
PersonalIncome04 = PersonalIncome04[1::]
PersonalIncome05 = PersonalIncome05[1::]
PersonalIncome06 = PersonalIncome06[1::]

Population04 = Population04[1::]
Population05 = Population05[1::]
Population06 = Population06[1::]

PerCapita04 = PerCapita04[1::]
PerCapita05 = PerCapita05[1::]
PerCapita06 = PerCapita06[1::]

# %%
#Personal Income 2004
fig,plot = plt.subplots(figsize=(20, 20))
width = 2.25
ind = np.arange(len(PersonalIncome04.data))
plot.bar(PersonalIncome04.GeoName,PersonalIncome04.data, color="blue")
#plot.set_yticks(ind+width/2)
#plot.set_yticklabels(PersonalIncome04.data, minor=False)
#plot.set_xticks(ind/2)
plot.set_xticklabels(PersonalIncome04.GeoName,minor=False,fontsize = 20)
plt.title("Annual Personal Income in each state in 2004")
plt.xlabel('States')
plt.ylabel('Millions of Dollars')
plt.savefig("PersonalIncome04.png")
for i in plot.patches:
    # get_x pulls left or right; get_height pushes up or down
    plot.text(i.get_x()+.04, i.get_height()+12000, \
            str(round((i.get_height()), 2)), fontsize=36, color='black')

# %%
#Personal Income 2005
fig,plot = plt.subplots(figsize=(20, 20))
width = 2.25
ind = np.arange(len(PersonalIncome05.data))
plot.bar(PersonalIncome05.GeoName,PersonalIncome05.data, color="blue")
#plot.set_yticks(ind+width/2)
#plot.set_yticklabels(PersonalIncome05.data, minor=False)
#plot.set_xticks(ind/2)
plot.set_xticklabels(PersonalIncome05.GeoName,minor=False,fontsize = 20)
plt.title("Annual Personal Income in each state in 2005")
plt.xlabel('States')
plt.ylabel('Millions of Dollars')
plt.savefig("PersonalIncome05.png")
for i in plot.patches:
    # get_x pulls left or right; get_height pushes up or down
    plot.text(i.get_x()+.04, i.get_height()+12000, \
            str(round((i.get_height()), 2)), fontsize=36, color='black')

# %%
#Personal Income 2006
fig,plot = plt.subplots(figsize=(20, 20))
width = 2.25
ind = np.arange(len(PersonalIncome06.data))
plot.bar(PersonalIncome06.GeoName,PersonalIncome06.data, color="blue")
#plot.set_yticks(0,PersonalIncome06.max()-1)
#plot.set_yticklabels(PersonalIncome06.data, minor=False)
#plot.set_xticks(ind/2)
plot.set_xticklabels(PersonalIncome06.GeoName,minor=False,fontsize = 20)
plt.title("Annual Personal Income in each state in 2006")
plt.xlabel('States')
plt.ylabel('Millions of Dollars')
plt.savefig("PersonalIncome06.png")
# set individual bar lables using above list
for i in plot.patches:
    # get_x pulls left or right; get_height pushes up or down
    plot.text(i.get_x()+.04, i.get_height()+12000, \
            str(round((i.get_height()), 2)), fontsize=36, color='black')

# %%
#Personal Income Comparisons
PI = pd.concat([PersonalIncome04,PersonalIncome05,PersonalIncome06], axis=0, ignore_index=False)
PI['Years'] = (len(PersonalIncome04.data)*(2004,) + len(PersonalIncome05.data)*(2005,) + len(PersonalIncome06.data)*(2006,))
PI
combined = sns.factorplot(x='GeoName', y='data', hue="Years",kind='bar', data=PI)
combined.set_axis_labels('States', 'Millions of Dollars')
plt.subplots_adjust(top=0.9)
combined.fig.suptitle('Total Personal Income over 3 years')
# Out:
# /Users/vidyagopal/opt/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(0.5, 0.98, 'Total Personal Income over 3 years')

# %%
#Population 2004
fig,plot = plt.subplots(figsize=(20, 20))
width = 2.25
ind = np.arange(len(PersonalIncome04.data))
plot.bar(PersonalIncome04.GeoName,PersonalIncome04.data, color="blue")
plot.set_xticklabels(PersonalIncome04.GeoName,minor=False,fontsize = 20)
plt.title("Population in each state in 2004")
plt.xlabel('States')
plt.ylabel('People')
plt.savefig("Population04.png")
for i in plot.patches:
    # get_x pulls left or right; get_height pushes up or down
    plot.text(i.get_x()+.04, i.get_height()+12000, \
            str(round((i.get_height()), 2)), fontsize=36, color='black')

# %%
#Population 2005
fig,plot = plt.subplots(figsize=(20, 20))
width = 2.25
ind = np.arange(len(Population05.data))
plot.bar(Population05.GeoName,Population05.data, color="blue")
plot.set_xticklabels(Population05.GeoName,minor=False,fontsize = 20)
plt.title("Population in each state in 2005")
plt.xlabel('States')
plt.ylabel('Population')
plt.savefig("Population05.png")
for i in plot.patches:
    # get_x pulls left or right; get_height pushes up or down
    plot.text(i.get_x()+.04, i.get_height()+12000, \
            str(round((i.get_height()), 2)), fontsize=36, color='black')

# %%
#Population 2006
fig,plot = plt.subplots(figsize=(20, 20))
width = 2.25
ind = np.arange(len(Population06.data))
plot.bar(Population06.GeoName,Population06.data, color="blue")
plot.set_xticklabels(Population06.GeoName,minor=False,fontsize = 20)
plt.title("Population in each state in 2006")
plt.xlabel('States')
plt.ylabel('People')
plt.savefig("Population06.png")
# set individual bar lables using above list
for i in plot.patches:
    # get_x pulls left or right; get_height pushes up or down
    plot.text(i.get_x()+.04, i.get_height()+12000, \
            str(round((i.get_height()), 2)), fontsize=36, color='black')

# %%
#Population Comparisons
PI = pd.concat([Population04,Population05,Population06], axis=0, ignore_index=False)
PI['Years'] = (len(Population04.data)*(2004,) + len(Population05.data)*(2005,) + len(Population06.data)*(2006,))
PI
combined = sns.factorplot(x='GeoName', y='data', hue="Years",kind='bar', data=PI)
combined.set_axis_labels('States', 'People')
plt.subplots_adjust(top=0.9)
combined.fig.suptitle('Population over 3 years')
# Out:
# Text(0.5, 0.98, 'Population over 3 years')

# %%
#Income Per Capita 2004
fig,plot = plt.subplots(figsize=(20, 20))
width = 2.25
ind = np.arange(len(PerCapita04.data))
plot.bar(PerCapita04.GeoName,PerCapita04.data, color="blue")
plot.set_xticklabels(PerCapita04.GeoName,minor=False,fontsize = 20)
plt.title("Per Capita Personal Income in each state in 2004")
plt.xlabel('States')
plt.ylabel('Dollars')
plt.savefig("PerCapita04.png")
for i in plot.patches:
    # get_x pulls left or right; get_height pushes up or down
    plot.text(i.get_x()+.04, i.get_height()+200, \
            str(round((i.get_height()), 2)), fontsize=36, color='black')

# %%
#Income Per Capita 2005
fig,plot = plt.subplots(figsize=(20, 20))
width = 2.25
ind = np.arange(len(PerCapita05.data))
plot.bar(PerCapita05.GeoName,PerCapita05.data, color="blue")
plot.set_xticklabels(PerCapita05.GeoName,minor=False,fontsize = 20)
plt.title("Annual Personal Income in each state in 2005")
plt.xlabel('States')
plt.ylabel('Dollars')
plt.savefig("PerCapita05.png")
# set individual bar lables using above list
for i in plot.patches:
    # get_x pulls left or right; get_height pushes up or down
    plot.text(i.get_x()+.04, i.get_height()+200, \
            str(round((i.get_height()), 2)), fontsize=36, color='black')

# %%
#Income Per Capita 2006
fig,plot = plt.subplots(figsize=(20, 20))
width = 2.25
ind = np.arange(len(PerCapita06.data))
plot.bar(PerCapita06.GeoName,PerCapita06.data, color="blue")
plot.set_xticklabels(PerCapita06.GeoName,minor=False,fontsize = 20)
plt.title("Annual Personal Income in each state in 2006")
plt.xlabel('States')
plt.ylabel('Dollars')
plt.savefig("PerCapita06.png")
# set individual bar lables using above list
for i in plot.patches:
    # get_x pulls left or right; get_height pushes up or down
    plot.text(i.get_x()+.04, i.get_height()+200, \
            str(round((i.get_height()), 2)), fontsize=36, color='black')

# %%
#Income Per Capita Comparisons
PI = pd.concat([PerCapita04,PerCapita05,PerCapita06], axis=0, ignore_index=False)
PI['Years'] = (len(PerCapita04.data)*(2004,) + len(PerCapita05.data)*(2005,) + len(PerCapita06.data)*(2006,))
PI
combined = sns.factorplot(x='GeoName', y='data', hue="Years",kind='bar', data=PI)
combined.set_axis_labels('States', 'Dollars')
plt.subplots_adjust(top=0.9)
combined.fig.suptitle('Personal Income per Capita over 3 years')
# Out:
# Text(0.5, 0.98, 'Personal Income per Capita over 3 years')
